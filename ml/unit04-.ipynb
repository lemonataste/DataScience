# %% [markdown]
# plt.plot(데이터셋) 그래프 그리기

# %%
import matplotlib.pyplot as plt

plt.plot([10,20,30,40]) #y값이 주어지면, 자동으로 x값을 0부터 1씩 증가

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4],[12,43,25,15]) # (x,y) 함수에 데이터 입력

# %%
import matplotlib.pyplot as plt

plt.title('plotting')
plt.plot([1,2,3,4],[12,43,25,15]) # (x,y) 함수에 데이터 입력

# %%
import matplotlib.pyplot as plt

plt.title('plotting')
plt.plot([10,20,30,40],label='asc')#증가를 의미하는 asc 범례
plt.plot([40,30,20,10], label = 'desc') #감소를 의미하는 desc범례

plt.legend(loc=6)

# %%
import matplotlib.pyplot as plt

plt.title('color')
plt.plot([10,20,30,40],color= 'skyblue',label='skyblue')#하늘색 그래프
plt.plot([40,30,20,10],'pink', label = 'pink') #분홍색 그래프

plt.legend(loc=10)  #그래프에 범례 속성 추가

# %%
import matplotlib.pyplot as plt

plt.title('color')
plt.plot([10,20,30,40],color= 'r',label='red')#기본 색상은 약자로 가능
plt.plot([40,30,20,10],'g', label = 'green') #

plt.legend(loc=10)  #그래프에 범례 속성 추가

# %%
import matplotlib.pyplot as plt

plt.title('linestyle')
plt.plot([10,20,30,40],color= 'skyblue',linestyle='--',label='dashed')#하늘색 그래프
plt.plot([40,30,20,10],'pink',ls=':',label = 'dotted') #분홍색 그래프

plt.legend(loc=10)  #그래프에 범례 속성 추가

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10,20,30,40],'r.',label='circle')#하늘색 그래프
plt.plot([40,30,20,10],'g^',label = 'tri') #분홍색 그래프

plt.legend(loc=10)  #그래프에 범례 속성 추가

# %%
import matplotlib.pyplot as plt

plt.title('marker')
plt.plot([10,20,30,40],'r.-',label='circle')#하늘색 그래프
plt.plot([40,30,20,10],'g^--',label = 'tri') #분홍색 그래프

plt.legend(loc=10)  #그래프에 범례 속성 추가

# %%
import csv
import matplotlib.pyplot as plt #1) 라이브러리 임포트

f = open('/content/seoul.csv', encoding='cp949')
data = csv.reader(f)
header = next(data)

res = [] #결측치를 제거한 최고기온 리스트

for row in data :
  if row [-1] != '':   # 최고기온이 ""(빈문자열)이 아니면,
    res.append(float(row[-1]))

res

plt.figure(dpi=200)  #표 사이즈와 해상도
plt.plot(res,'r')
plt.show()
